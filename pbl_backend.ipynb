# %%
import pandas as pd
import numpy as np

# %%
ratings=pd.read_csv(r"C:\Users\shiju\Downloads\Ratings.csv.zip")
users=pd.read_csv(r"C:\Users\shiju\Downloads\Users.csv.zip")
books=pd.read_csv(r"C:\Users\shiju\Downloads\Books.csv.zip")
# Out:
# C:\Users\shiju\AppData\Local\Temp\ipykernel_11068\1156352984.py:3: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books=pd.read_csv(r"C:\Users\shiju\Downloads\Books.csv.zip")

# %%
books.head(3)
# Out:
#          ISBN            Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448   Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018          Clara Callan  Richard Bruce Wright                2001
# 2  0060973129  Decision in Normandy          Carlo D'Este                1991
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2          HarperPerennial  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.head(2)
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5

# %% [markdown]
# ## popularity based

# %%
rb=books.merge(ratings,on='ISBN')

# %%
rb.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
# ...

# %%
rb.describe()
# Out:
#             User-ID   Book-Rating
# count  1.031136e+06  1.031136e+06
# mean   1.405945e+05  2.839051e+00
# std    8.052466e+04  3.854157e+00
# min    2.000000e+00  0.000000e+00
# 25%    7.041500e+04  0.000000e+00
# 50%    1.412100e+05  0.000000e+00
# 75%    2.114260e+05  7.000000e+00
# max    2.788540e+05  1.000000e+01

# %%
rb['ISBN']
# Out:
# 0          0195153448
# 1          0002005018
# 2          0002005018
# 3          0002005018
# 4          0002005018
#               ...
# 1031131    0440400988
# 1031132    0525447644
# 1031133    006008667X
# 1031134    0192126040
# 1031135    0767409752
# Name: ISBN, Length: 1031136, dtype: object

# %%
rb
# Out:
#                ISBN                                         Book-Title  \
# 0        0195153448                                Classical Mythology
# 1        0002005018                                       Clara Callan
# 2        0002005018                                       Clara Callan
# 3        0002005018                                       Clara Callan
# 4        0002005018                                       Clara Callan
# ...             ...                                                ...
# 1031131  0440400988                         There's a Bat in Bunk Five
# 1031132  0525447644                            From One to One Hundred
# 1031133  006008667X  Lily Dale : The True Story of the Town that Ta...
# 1031134  0192126040                        Republic (World's Classics)
# 1031135  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                   Book-Author Year-Of-Publication  \
# 0          Mark P. O. Morford                2002
# ...

# %%
num_rating_df = rb.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
# [241071 rows x 2 columns]

# %%
avg_rating_df = rb.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_rating'},inplace=True)
avg_rating_df
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...    2.250000
# 1                                   Always Have Popsicles    0.000000
# 2                    Apple Magic (The Collector's series)    0.000000
# 3        Ask Lily (Young Women of Faith: Lily Series, ...    8.000000
# 4        Beyond IBM: Leadership Marketing and Finance ...    0.000000
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.    0.000000
# 241067                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 241068                                Ã?Â?sterlich leben.    7.000000
# 241069                              Ã?Â?stlich der Berge.    2.666667
# 241070                                  Ã?Â?thique en toc    4.000000
#
# [241071 rows x 2 columns]

# %%
final_rb= num_rating_df.merge(avg_rating_df,on='Book-Title')
final_rb
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                                   Always Have Popsicles            1
# 2                    Apple Magic (The Collector's series)            1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...            1
# 4        Beyond IBM: Leadership Marketing and Finance ...            1
# ...                                                   ...          ...
# 241066                                      Ã?Â?lpiraten.            2
# 241067                     Ã?Â?rger mit Produkt X. Roman.            4
# 241068                                Ã?Â?sterlich leben.            1
# 241069                              Ã?Â?stlich der Berge.            3
# 241070                                  Ã?Â?thique en toc            2
#
#         avg_rating
# 0         2.250000
# 1         0.000000
# 2         0.000000
# 3         8.000000
# ...

# %%
final_rb=final_rb[final_rb['num_ratings']>=250].sort_values('avg_rating',ascending=False)
final_rb
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# ...                                                   ...          ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))          265
# 233635                                           Whispers          286
# 143377                                  Presumed Innocent          294
# 94382                                        Isle of Dogs          288
# 234951                                        Wild Animus         2502
#
#         avg_rating
# 80434     5.852804
# 80422     5.824289
# 80441     5.737410
# 80426     5.501441
# ...

# %%
final_rb
# Out:
#                                                Book-Title  num_ratings  \
# 80434   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 80422        Harry Potter and the Goblet of Fire (Book 4)          387
# 80441      Harry Potter and the Sorcerer's Stone (Book 1)          278
# 80426   Harry Potter and the Order of the Phoenix (Boo...          347
# 80414    Harry Potter and the Chamber of Secrets (Book 2)          556
# ...                                                   ...          ...
# 227701       Vinegar Hill (Oprah's Book Club (Paperback))          265
# 233635                                           Whispers          286
# 143377                                  Presumed Innocent          294
# 94382                                        Isle of Dogs          288
# 234951                                        Wild Animus         2502
#
#         avg_rating
# 80434     5.852804
# 80422     5.824289
# 80441     5.737410
# 80426     5.501441
# ...

# %%
final_rb=final_rb.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author_x','num_ratings','avg_rating','Image-URL-S']].head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11068\1183328908.py in <module>
# ----> 1 final_rb=final_rb.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author_x','num_ratings','avg_rating','Image-URL-S']].head(50)
#
# E:\balmucodes\anac\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3509             if is_iterator(key):
#    3510                 key = list(key)
# -> 3511             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3512
#    3513         # take() does not accept boolean indexers
#
# E:\balmucodes\anac\lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    5794             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5795
# -> 5796         self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
final_rb

# %% [markdown]
# ## content based

# %%
rb_content= num_rating_df.merge(avg_rating_df,on='Book-Title')
proper_rb=rb_content.merge(books,on="Book-Title")[['Book-Title','num_ratings','avg_rating','Book-Author','Publisher','Image-URL-S']]

# %%
proper_rb[proper_rb['Book-Author']=="Patricia Cornwell"].sort_values('avg_rating',ascending=False).head(10)

# %%
def authorb(author):
    res=proper_rb[proper_rb['Book-Author']==author].sort_values('avg_rating',ascending=False).head(10)
    data=[]
    for i in res:
        item = []
        item.extend(list(proper_rb.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(proper_rb.drop_duplicates('Book-Title')['Image-URL-S'].values))
        
        data.append(item)
    return data

# %%
authorb('J. K. Rowling')

# %%
books['Image-URL-S'].reset_index()

# %% [markdown]
# ## collaborative filtering

# %%
x=rb.groupby('User-ID').count()['Book-Rating']>200
ex_users=x[x].index

# %%
filtered_user=rb[rb['User-ID'].isin(ex_users)]

# %%
filtered_user
# Out:
#                ISBN                                         Book-Title  \
# 3        0002005018                                       Clara Callan
# 6        0002005018                                       Clara Callan
# 7        0002005018                                       Clara Callan
# 10       0002005018                                       Clara Callan
# 21       0374157065  Flu: The Story of the Great Influenza Pandemic...
# ...             ...                                                ...
# 1031124  0231128444                      Slow Food(The Case For Taste)
# 1031125  0520242335  Strong Democracy : Participatory Politics for ...
# 1031126  0762412119  Burpee Gardening Cyclopedia: A Concise, Up to ...
# 1031127  1582380805  Tropical Rainforests: 230 Species in Full Colo...
# 1031128  1845170423                                  Cocktail Classics
#
#                    Book-Author Year-Of-Publication  \
# 3         Richard Bruce Wright                2001
# ...

# %%
y=filtered_user.groupby('Book-Title').count()['Book-Rating']>=50
best_books=y[y].index

# %%
final_filter=filtered_user[filtered_user['Book-Title'].isin(best_books)]

# %%
final_filter
# Out:
#                ISBN                       Book-Title      Book-Author  \
# 31       0399135782           The Kitchen God's Wife          Amy Tan
# 33       0399135782           The Kitchen God's Wife          Amy Tan
# 34       0399135782           The Kitchen God's Wife          Amy Tan
# 38       0399135782           The Kitchen God's Wife          Amy Tan
# 39       0399135782           The Kitchen God's Wife          Amy Tan
# ...             ...                              ...              ...
# 1028414  1878702831                           Echoes      Nancy Morse
# 1028600  0394429869  I Know Why the Caged Bird Sings     Maya Angelou
# 1028602  0449001164                      The Promise      CHAIM POTOK
# 1028815  0743527631         The Pillars of the Earth      Ken Follett
# 1028817  0745168086              The Handmaid's Tale  Margaret Atwood
#
#         Year-Of-Publication                      Publisher  \
# 31                     1991               Putnam Pub Group
# ...

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
final_filter=final_filter.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
final_filter.fillna(0,inplace=True)

# %%
final_filter
# Out:
# User-ID                                             254     2276    2766    \
# Book-Title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Bend in the Road                                     0.0     0.0     7.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
import sklearn

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(final_filter)

# %%
similarity_scores
# Out:
# array([[1.        , 0.10255025, 0.01220856, ..., 0.12110367, 0.07347567,
#         0.04316046],
#        [0.10255025, 1.        , 0.2364573 , ..., 0.07446129, 0.16773875,
#         0.14263397],
#        [0.01220856, 0.2364573 , 1.        , ..., 0.04558758, 0.04938579,
#         0.10796119],
#        ...,
#        [0.12110367, 0.07446129, 0.04558758, ..., 1.        , 0.07085128,
#         0.0196177 ],
#        [0.07347567, 0.16773875, 0.04938579, ..., 0.07085128, 1.        ,
#         0.10602962],
#        [0.04316046, 0.14263397, 0.10796119, ..., 0.0196177 , 0.10602962,
#         1.        ]])

# %%
def recommend(book):
    index=np.where(final_filter.index==(book))[0][0]
    similarity=sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    data = []
    for i in similarity:
        item = []
        temp_df = books[books['Book-Title'] == final_filter.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend('1984')
# Out:
# [['Animal Farm',
#   'George Orwell',
#   'http://images.amazon.com/images/P/0451526341.01.MZZZZZZZ.jpg'],
#  ["The Handmaid's Tale",
#   'Margaret Atwood',
#   'http://images.amazon.com/images/P/0449212602.01.MZZZZZZZ.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'http://images.amazon.com/images/P/0060809833.01.MZZZZZZZ.jpg'],
#  ['The Vampire Lestat (Vampire Chronicles, Book II)',
#   'ANNE RICE',
#   'http://images.amazon.com/images/P/0345313860.01.MZZZZZZZ.jpg']]
